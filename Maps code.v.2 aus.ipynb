# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import matplotlib.patches as patches
from highlight_text import fig_text

# %% [markdown]
# ### Importing data

# %%
edata = pd.read_csv("C:\\Users\\amaia\\Downloads\\ML project\\lung_cancer_mortality_data_large_v2.csv")
#renaming the countys column to match the geopandas file for when we merge
edata = edata.rename(columns={"country" : "Country"})

# %%
#For reading the geopanadas files
import geopandas as gpd

world = gpd.read_file("C:\\Users\\amaia\\Downloads\\ne_110m_admin_0_countries\\ne_110m_admin_0_countries.shp")
world["Country"]
# filter on europe only
#europe = world[world['CONTINENT'] == 'Europe']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 5
#       2 import geopandas as gpd
#       4 world = gpd.read_file("C:\\Users\\amaia\\Downloads\\ne_110m_admin_0_countries\\ne_110m_admin_0_countries.shp")
# ----> 5 world["Country"]
#
# File ~\anaconda3\Lib\site-packages\geopandas\geodataframe.py:1459, in GeoDataFrame.__getitem__(self, key)
#    1453 def __getitem__(self, key):
#    1454     """
#    1455     If the result is a column containing only 'geometry', return a
#    1456     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1457     return a GeoDataFrame.
#    1458     """
# -> 1459     result = super().__getitem__(key)
#    1460     # Custom logic to avoid waiting for pandas GH51895
#    1461     # result is not geometry dtype for multi-indexes
#    1462     if (
#    1463         pd.api.types.is_scalar(key)
#    1464         and key == ""
#    (...)
#    1467         and not is_geometry_type(result)
#    1468     ):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Country'

# %% [markdown]
# ### Subsetting data to calculate % mortality of patients by region

# %%
#LOOKING AT MORTALITY RATE BY COUNTRY

#count of deaths by country
survived_false= edata[(edata["survived"] == 0)]
count_map = survived_false.groupby(["Country"]).size().reset_index(name="deaths")

#total count of patients by country
total_group_map= edata.groupby(["Country"]).size().reset_index(name="total")

#CREATING SURVIVAL RATE METRIC COUNT(SURIVIED)/ COUNT(TOTAL DIGANOSED)
count_map["mortality_rate"] = count_map["deaths"]/total_group_map["total"]

#DROPPING DEATHS AS WE NOW HAVE MORTALITY % AS A VALUE NOW
count_map.drop(["deaths"], axis = 1, inplace = True)
#count_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 #LOOKING AT MORTALITY RATE BY COUNTRY
#       2
#       3 #count of deaths by country
# ----> 4 survived_false= edata[(edata["survived"] == 0)]
#       5 count_map = survived_false.groupby(["Country"]).size().reset_index(name="deaths")
#       7 #total count of patients by country
#
# NameError: name 'edata' is not defined

# %% [markdown]
# ### Merging data with geopandas data

# %%
#merging data on country
data = europe.merge(count_map, how='left',
                    left_on='NAME', right_on='Country')

#droping countries in the geopandas which are not in our data 
data.dropna(subset=['mortality_rate'], inplace=True)
#rounding number and creating a percentage
data['mortality_rate'] = round(data['mortality_rate']*100, 1)

# %%
# initialize the figure
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

# define colors
cmap = cm.YlOrRd
min_rate, max_rate = 68, 84.6
norm = mcolors.Normalize(vmin=min_rate, vmax=max_rate)

# create the plot
data.plot(column='mortality_rate', cmap=cmap, norm=norm, ax=ax,edgecolor='black', linewidth=0.3)

# custom axis - creates the graph axis but removes them from being displayed
ax.set_xlim(-15, 35)
ax.set_ylim(32, 72)
ax.axis('off')


fig.text(0.1, 0.7, 'Mortality rate of \nlung cancer patients\nacross Europe',
         fontsize=20, fontweight='bold', fontfamily='serif')

# compute centroids for annotations
data_projected = data.to_crs(epsg=3035)
data_projected['centroid'] = data_projected.geometry.centroid
data['centroid'] = data_projected['centroid'].to_crs(data.crs)
countries_to_annotate = ['France',
                         'Lithuania', 'Finland', 'Austria', 'Croatia', 'Portugal', 'Bulgaria', 'Poland', "Spain", "Ireland"]

#these are the positions of the text on the countries
adjustments = {
    'France': (9, 3),
    'Spain': (0, -1),
    'Italy': (-2.4, 2),
    'Lithuania': (0, -0.6),
    'Finland': (0, -2.5),
    'Bulgaria': (-0.1, -0.7),
    'Ireland': (0, -1),
    'Croatia': (1.5, -1),
    'Malta': (0, -1),
    'Austria': (0.1, -0.5),
    'Portugal': (-4.5, -1),
    'Poland': (0, -1),
}
# annotate countries
for country in countries_to_annotate:

    # get centroid
    centroid = data.loc[data['NAME'] == country, 'centroid'].values[0]
    x, y = centroid.coords[0]

    # get corrections
    x += adjustments[country][0]
    y += adjustments[country][1]

    # get rate and annotate
    rate = data.loc[data['NAME'] == country, 'mortality_rate'].values[0]
    ax.annotate(f'{country[:3]} {rate}%', (x, y), textcoords="offset points", xytext=(5, 5),
                ha='center', fontsize=9, fontfamily='DejaVu Sans', color='black', fontweight = "bold")

# display the plot
plt.tight_layout()
#plt.show()

# %% [markdown]
# ### Plotting 'Health score'
# This is a metric which will combine bmi, cholesterol level, hypotension presence, cirrhosis presence, asthma presence and other cancer presence
#
# To be able to combine the values of these the values which are continous must be scaled

# %%
from sklearn.preprocessing import StandardScaler

#Creating a dataframe of all values which are needed for the score
scaled_data =  edata[["Country","bmi","cholesterol_level", "hypertension", "asthma" , "cirrhosis", "other_cancer"]]

#scaling continuous columns
scaler = StandardScaler()
scaled_data.loc[:,['bmi', "cholesterol_level"]] = scaler.fit_transform(scaled_data[['bmi', "cholesterol_level"]])

# %%
#Creating the score by adding the values together
scaled_data.loc[:,"score"]  = (scaled_data["bmi"] + scaled_data["cholesterol_level"] + scaled_data["hypertension"] 
                        + scaled_data["asthma"] + scaled_data["cirrhosis"] + scaled_data["other_cancer"])
# Out:
# C:\Users\amaia\AppData\Local\Temp\ipykernel_11492\719994158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scaled_data.loc[:,"score"]  = (scaled_data["bmi"] + scaled_data["cholesterol_level"] + scaled_data["hypertension"]

# %% [markdown]
# ## Grouping the data by country and calculating a mean score for plotting

# %%
test = scaled_data.groupby(["Country"])["score"].mean().reset_index(name="health")

# %%
#Merging data as previous figure
data_score = europe.merge(test, how='left',
                    left_on='NAME', right_on='Country')

data_score.dropna(subset=['health'], inplace=True)

# %%
#changing data type as for some reason it was object
data_score["health"] = data_score["health"].astype(float)
#rounding to 2 d.p.
data_score['health'] = round(data_score['health'], 2)

# %%
# initialize the figure
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

# define colors
cmap = cm.get_cmap('Blues')
min_rate, max_rate = data_score['health'].min(), data_score['health'].max()
norm = mcolors.Normalize(vmin=min_rate, vmax=max_rate)

# create the plot
data_score.plot(column='health', cmap=cmap, norm=norm, ax=ax,edgecolor='black', linewidth=0.2)

# custom axis
ax.set_xlim(-15, 35)
ax.set_ylim(32, 72)
ax.axis('off')

fig.text(0.1, 0.8, 'Mean commoditiy score\nof lung cancer\npatients by country',
         fontsize=20, fontweight='bold', fontfamily='serif')

# compute centroids for annotations
data_projected = data_score.to_crs(epsg=3035)
data_projected['centroid'] = data_projected.geometry.centroid
data_score['centroid'] = data_projected['centroid'].to_crs(data_score.crs)
countries_to_annotate = ['France', 'Lithuania', 'Finland', 'Croatia', 'Portugal', 'Bulgaria', "Italy", "Sweden", "Germany", "Belgium", "Netherlands"]
adjustments = {
    'France': (9, 3),
    'Italy': (-2.4, 2),
    'Lithuania': (0, -0.6),
    'Finland': (0, -2.5),
    'Romania': (0, -0.5),
    'Bulgaria': (0.1, -0.4),
    'Greece': (-1.2, -0.8),
    'Croatia': (1.1, -1),
    'Cyprus': (0, -1),
    'Ireland': (0, -1),
    'Malta': (0, -1),
    'Slovenia': (0, -1),
    'Slovakia': (-0.7, -0.8),
    'Estonia': (0, -0.7),
    'Latvia': (1, -0.5),
    'Belgium': (-3, 0.5),
    'Austria': (0, -1),
    'Spain': (0, -1),
    'Portugal': (-4.5, -1),
    'Luxembourg': (0, -1),
    'Germany': (-0.2, 0),
    'Hungary': (-0.3, -1),
    'Czechia': (0, -1),
    'Poland': (0, -1),
    'Sweden': (-1.5, -1),
    'Denmark': (0, -1),
    'Netherlands': (-3.4, 0.2),
    'Switzerland': (0, -0.5),
}
# annotate countries
for country in countries_to_annotate:

    # get centroid
    centroid = data_score.loc[data['NAME'] == country, 'centroid'].values[0]
    x, y = centroid.coords[0]

    # get corrections
    x += adjustments[country][0]
    y += adjustments[country][1]

    # get rate and annotate
    rate = data_score.loc[data_score['NAME'] == country, 'health'].values[0]
    ax.annotate(f'{country[:3]} {rate}', (x, y), textcoords="offset points", xytext=(5, 5),
               ha='center', fontsize=9, fontfamily='DejaVu Sans', color='black', fontweight = "bold")

# display the plot
plt.tight_layout()
#plt.show()
plt.savefig("healthscore.png", transparent = True, dpi =300)
# Out:
# C:\Users\amaia\AppData\Local\Temp\ipykernel_11492\337152888.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('Blues')

# %% [markdown]
# ## exposure to smoke

# %%
#only people who have smoked, currently smoked or been exposed to smoke
smoking_positive= edata[(edata["smoking_status"] != "Never Smoked")]

count_smokers = smoking_positive.groupby(["Country"]).size().reset_index(name="smokers")

#total count
total_group_by_smoking= edata.groupby(["Country"]).size().reset_index(name="total")


#create percentage of patients exposed
count_smokers["smoking exposure %"] = count_smokers["smokers"]/total_group_by_smoking["total"]*100
count_smokers.drop(["smokers"], axis = 1, inplace = True)
count_smokers.sort_values(by = "smoking exposure %", ascending = False)
# Out:
#            Country  smoking exposure %
# 9           France           75.408353
# 2         Bulgaria           75.383706
# 16       Lithuania           75.323375
# 19     Netherlands           75.176740
# 21        Portugal           75.155135
# 1          Belgium           75.124867
# 10         Germany           75.084244
# 11          Greece           75.066512
# 23        Slovakia           75.059199
# 20          Poland           75.052341
# 18           Malta           75.042981
# 3          Croatia           75.012853
# 26          Sweden           74.990327
# 0          Austria           74.968799
# 22         Romania           74.968486
# 4           Cyprus           74.956379
# 5   Czech Republic           74.953428
# 8          Finland           74.931831
# 13         Ireland           74.915786
# 25           Spain           74.913833
# 17      Luxembourg           74.898618
# 24        Slovenia           74.852846
# 14           Italy           74.807515
# 7          Estonia           74.784182
# 12         Hungary           74.764223
# 15          Latvia           74.739583
# 6          Denmark           74.623617

# %%
data_smoker = europe.merge(count_smokers, how='left',
                    left_on='NAME', right_on='Country')

data_smoker.dropna(subset=['smoking exposure %'], inplace=True)

data_smoker['smoking exposure %'] = round(data_smoker['smoking exposure %'], 2)
data_smoker["NAME"]
# Out:
# 2          France
# 3          Sweden
# 6          Poland
# 7         Austria
# 8         Hungary
# 10        Romania
# 11      Lithuania
# 12         Latvia
# 13        Estonia
# 14        Germany
# 15       Bulgaria
# 16         Greece
# 18        Croatia
# 20     Luxembourg
# 21        Belgium
# 22    Netherlands
# 23       Portugal
# 24          Spain
# 25        Ireland
# 26          Italy
# 27        Denmark
# 30       Slovenia
# 31        Finland
# 32       Slovakia
# Name: NAME, dtype: object

# %%
#data_smoker['smoking exposure %'].min()
data_smoker['smoking exposure %'].min()
# Out:
# 74.62

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import geopandas as gpd

# Assuming `data_smoker` is a GeoDataFrame with the necessary data
# Initialize the figure
fig, ax = plt.subplots(1, 1, figsize=(15, 9))

# Define colors
cmap = cm.get_cmap('YlGn')
norm = mcolors.Normalize(vmin=74.62, vmax=75.41)

# Create the plot
data_smoker.plot(column='smoking exposure %', cmap=cmap, norm=norm, ax=ax, edgecolor='black', linewidth=0.2)

# Custom axis
ax.set_xlim(-15, 35)
ax.set_ylim(32, 72)
ax.axis('off')

# Title
fig.text(0.1, 0.7, 'Percentage of lung cancer patients \n with a history of smoking \n or passive exposure to smoke',
         fontsize=20, fontweight='bold', fontfamily='serif')

# Compute centroids for annotations
data_projected = data_smoker.to_crs(epsg=3035)
data_projected['centroid'] = data_projected.geometry.centroid
data_smoker['centroid'] = data_projected['centroid'].to_crs(data_smoker.crs)

# Countries to annotate and their adjustments
countries_to_annotate = ['France', 'Lithuania', 'Finland', 'Austria', 'Croatia', 'Portugal', 'Bulgaria', 'Spain', 'Sweden']
adjustments = {
    'France': (9, 3),
    'Lithuania': (0, -0.6),
    'Finland': (0, -2.5),
    'Austria': (0, -1),
    'Croatia': (1, -1.6),
    'Portugal': (-5, -0.3),
    'Bulgaria': (6, -0.6),
    'Spain': (0, -1),
    'Sweden': (-1.5, -1),
}

# Annotate countries
for country in countries_to_annotate:
    # Get centroid
    centroid = data_smoker.loc[data_smoker['NAME'] == country, 'centroid'].values[0]
    x, y = centroid.x, centroid.y

    # Apply corrections
    x += adjustments[country][0]
    y += adjustments[country][1]

    # Get rate and annotate
    rate = data_smoker.loc[data_smoker['NAME'] == country, 'smoking exposure %'].values[0]
    ax.annotate(f'{country[:3]} {rate:.2f}%', (x, y), textcoords="offset points", xytext=(5, 5),
                ha='center', fontsize=9, fontfamily='DejaVu Sans', color='black', fontweight='bold')

#plt.show()

# display the plot
plt.tight_layout()

#plt.show()
plt.savefig("smoking.png", transparent = True, dpi =300)
# Out:
# C:\Users\amaia\AppData\Local\Temp\ipykernel_11492\778350080.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('YlGn')
